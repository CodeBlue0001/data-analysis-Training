# %% [markdown]
# <a href="https://colab.research.google.com/github/CodeBlue0001/data-analysis-Training/blob/main/data_analysis_day_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
import numpy as np

plt.plot([1,2,3,4,5],[0,9,8,7,6])
plt.show()

# %%
num1=int(input("Enter the first number: "))
num2=int(input("Enter the second number:"))
print("The sum of the number is",num1+num2)
# Out:
# Enter the first number: 5
# Enter the second number:25
# The sum of the number is 30

# %%
# area and peremeter of a rectangel
length=int(input("Enter the length: "))
breadth=int(input("Enter the breadth: "))
area=length*breadth
perimeter=2*(length+breadth)
print("The area of the rectangle is",area)
print( "The perimeter of the ractangle is:",perimeter)
# Out:
# Enter the length: 6
# Enter the breadth: 5
# The area of the rectangle is 30
# The perimeter of the ractangle is: 22

# %%
# area perimeter of a triangle
base=int(input("Enter the base: "))
height=int(input("Enter the height: "))
area_of_triangle=(1/2)*base*height
perimeter_of_triangle=3*base
print("The area of the triangle is:",area_of_triangle)

# %%
# simple interest
time=int(input("Enter the time: "))
rate_of_interest=int(input("Enter the rate of interest: "))
principal_amount=int(input("Enter the principal amount: "))
simple_interest=(time*rate_of_interest*principal_amount)/100
print("The simple interest is: ",simple_interest)
# Out:
# Enter the time: 5
# Enter the rate of interest: 2
# Enter the principal amount: 5200
# The simple interest is:  520.0

# %%
# celcias to farenhite
celciaus=int(input("Enter the celciaus: "))
farenhite=(celciaus*9/5)+3
print( "The conversion of the celciaus is:",farenhite)
# Out:
# Enter the celciaus: 100
# The conversion of the celciaus is: 183.0

# %%
# calculate speed
distance=int(input("Enter the distance (in Km): "))
time=int(input("Enter the time(in Hr): "))
speed=distance/time
print("The speed is:",speed)
# Out:
# Enter the distance: 500
# Enter the time: 2
# The speed is: 250.0

# %%
text='''python is easy
python is powerful
python is popular'''

print(text)
# Out:
# python is easy
# python is powerful
# python is popular

# %%
# write a program to print these senternses in separate lines: My favourite subject is math, I want to study Math hons. And I want to become Maths teacher
print("My favourite subject is math,\nI want to study Math hons.\nAnd I want to become Maths teacher")
# Out:
# My favourite subject is math,
# I want to study Math hons.
# And I want to become Maths teacher

# %%
word="python"
print(word[3])
# Out:
# h

# %%
print(text[3::])
text2="python is powerful"
print(text2[7],text2[11],text[14])
# last index
print(text2[-3])
# Out:
# hon is easy
# python is powerful
# python is popular
# i o
#
# f

# %%
# write a program to take a sentence using  user input and extract the 3rd charecter and the 2nd last charecter
string=str(input("Enter text: "))
print("3rd :",string[2],"2nd:",string[-2])
index=int(input("Enter the index number"))
print(index,"th charecter is :",string[index])
# Out:
# Enter text: ivenho
# 3rd : e 2nd: h
# Enter the index number4
# 4 th charecter is : h

# %%
char=str(input("Enter a charechter:"))
pos=string.find(char)
print("The position of the charecter is: ",pos)
# Out:
# Enter a charechter:5
# The position of the charecter is:  -1

# %%
# split function
sentence=str(input("Enter a sentence: "))
words=sentence.split()
print(words)
# first index of 1 index
print(words[1][1])
# Out:
# Enter a sentence: di[ayan sardar
# ['di[ayan', 'sardar']
# a

# %%
# input a sentence and extract a word which is in 3rd index and also extract the last charecter of that word
sen=str(input("Enter a sentence: "))
words=sen.split()
print(words[3][-1])
# Out:
# Enter a sentence: I am dipayan sardar I live in baruipur
# r
